# %% [markdown]
# ![image.png](attachment:87b9d76b-0b80-4ecd-bdd4-1e148ca19368.png)

# %%
from typing import List

class Solution:
    def findMaxAverage(self, nums: List[int], k: int) -> float:
        window_sum = sum(nums[:k])
        max_sum = window_sum

        for index in range(k, len(nums)):
            ele_to_sub = nums[index - k]
            ele_to_add = nums[index]

            window_sum += ele_to_add - ele_to_sub

            if window_sum > max_sum:
                max_sum = window_sum

        return max_sum/k

# %%
from typing import List

class Solution:
    def findMaxAverage(self, nums: List[int], k: int) -> float:
        window_sum = sum(nums[:k])
        max_sum = window_sum

        for index in range(k, len(nums)):
            window_sum += nums[index] - nums[index - k]

            if window_sum > max_sum:
                max_sum = window_sum

        return max_sum/k

# %% [markdown]
# ![image.png](attachment:bd91f19d-e8e8-497c-9c14-fe5b573b2449.png)

# %%
class Solution:
    def containsNearbyDuplicate(self, nums: List[int], k: int) -> bool:
        window_set = set()

        for i in range(len(nums)):
            if nums[i] in window_set:
                return True

            window_set.add(nums[i])

            if len(window_set) > k:
                window_set.remove(nums[i-k])
        
        return False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def numOfSubarrays(self, arr: List[int], k: int, threshold: int) -> int:
        target_sum = k * threshold

        window_sum = sum(arr[:k])
        count = 1 if window_sum >= target_sum else 0

        for i in range(k, len(arr)):
            window_sum += arr[i] - arr[i-k]
            if window_sum >= target_sum:
                count += 1
    
        return count
